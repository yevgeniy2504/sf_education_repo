# %%
import pandas as pd
# Убираем 'task_9/', так как мы уже внутри этой папки
df = pd.read_csv('./data/KaggleV2-May-2016 copy.csv')
print(df.head())
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,4))
df['No-show'].hist()
plt.title('Соотношение людей, которые пропускают приемы, к тем, кто этого не делает');

# %%
df['No-show'].value_counts(True)
# Out:
# No-show
# No     0.798067
# Yes    0.201933
# Name: proportion, dtype: float64

# %%
categorical_columns_names = ['Gender', 'Neighbourhood']
encoded_columns = pd.get_dummies(df, columns = categorical_columns_names)

# %%
import os
from opik import Opik
from opik.evaluation import evaluate

# os.environ["OPENAI_API_KEY"] = "OpenAI API key goes here"

os.environ["OPIK_API_KEY"] = "99KeV4WB80EqZybAsH3vOJkl8" 
os.environ["OPIK_WORKSPACE"] = "yevgeniy-karabekov"

from opik.evaluation.metrics import (Hallucination)
  
client = Opik()
dataset = client.get_dataset(name="dataset name placeholder")

def evaluation_task(dataset_item):
    # Replace with your LLM call
    llm_response = "your LLM response"

    result = {
        "input": "placeholder string",
        "output": "placeholder string"
    }

    return result

metrics = [Hallucination()]

eval_results = evaluate(
  experiment_name="my_evaluation",
  dataset=dataset,
  task=evaluation_task,
  scoring_metrics=metrics
)
