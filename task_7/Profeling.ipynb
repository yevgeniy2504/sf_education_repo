# %%
import pandas as pd
from ydata_profiling import ProfileReport

df = pd.read_csv("wine.csv")
profile = ProfileReport(df, title="Wine Dataset Profiling Report", explorative=True)
profile.to_file("wine_report.html")
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.5 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\ykarabekov\Documents\Python\Lib\asyncio\base_events.py", line 608, in run_forever
#     self._run_once()
#   File "C:\Users\ykarabekov\Documents\Python\Lib\asyncio\base_events.py", line 1936, in _run_once
#     handle._run()
#   File "C:\Users\ykarabekov\Documents\Python\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\IPython\core\interactiveshell.py", line 3098, in run_cell
#     result = self._run_cell(
#   File "c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\IPython\core\interactiveshell.py", line 3153, in _run_cell
#     result = runner(coro)
#   File "c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\IPython\core\interactiveshell.py", line 3365, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\IPython\core\interactiveshell.py", line 3610, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\IPython\core\interactiveshell.py", line 3670, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\ykarabekov\AppData\Local\Temp\ipykernel_22652\2739397434.py", line 2, in <module>
#     from ydata_profiling import ProfileReport
#   File "c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\ydata_profiling\__init__.py", line 10, in <module>
#     from ydata_profiling.compare_reports import compare  # isort:skip # noqa
#   File "c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\ydata_profiling\compare_reports.py", line 12, in <module>
#     from ydata_profiling.profile_report import ProfileReport
#   File "c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\ydata_profiling\profile_report.py", line 32, in <module>
#     from ydata_profiling.model.describe import describe as describe_df
#   File "c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\ydata_profiling\model\describe.py", line 20, in <module>
#     from ydata_profiling.model.pairwise import get_scatter_plot, get_scatter_tasks
#   File "c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\ydata_profiling\model\pairwise.py", line 6, in <module>
#     from ydata_profiling.visualisation.plot import scatter_pairwise
#   File "c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\ydata_profiling\visualisation\plot.py", line 5, in <module>
#     import matplotlib
#   File "c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\matplotlib\__init__.py", line 142, in <module>
#     from . import _api, _version, cbook, _docstring, rcsetup
#   File "c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\matplotlib\rcsetup.py", line 27, in <module>
#     from matplotlib.colors import Colormap, is_color_like
#   File "c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\matplotlib\colors.py", line 56, in <module>
#     from matplotlib import _api, _cm, cbook, scale
#   File "c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\matplotlib\scale.py", line 22, in <module>
#     from matplotlib.ticker import (
#   File "c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\matplotlib\ticker.py", line 138, in <module>
#     from matplotlib import transforms as mtransforms
#   File "c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\matplotlib\transforms.py", line 49, in <module>
#     from matplotlib._path import (
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 from ydata_profiling import ProfileReport
#       4 df = pd.read_csv("wine.csv")
#       5 profile = ProfileReport(df, title="Wine Dataset Profiling Report", explorative=True)
#
# File c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\ydata_profiling\__init__.py:10
#       6 import warnings  # isort:skip # noqa
#       8 import importlib.util  # isort:skip # noqa
# ---> 10 from ydata_profiling.compare_reports import compare  # isort:skip # noqa
#      11 from ydata_profiling.controller import pandas_decorator  # isort:skip # noqa
#      12 from ydata_profiling.profile_report import ProfileReport  # isort:skip # noqa
#
# File c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\ydata_profiling\compare_reports.py:12
#      10 from ydata_profiling.model import BaseDescription
#      11 from ydata_profiling.model.alerts import Alert
# ---> 12 from ydata_profiling.profile_report import ProfileReport
#      15 def _should_wrap(v1: Any, v2: Any) -> bool:
#      16     if isinstance(v1, (list, dict)):
#
# File c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\ydata_profiling\profile_report.py:32
#      30 from ydata_profiling.model import BaseDescription
#      31 from ydata_profiling.model.alerts import AlertType
# ---> 32 from ydata_profiling.model.describe import describe as describe_df
#      33 from ydata_profiling.model.sample import Sample
#      34 from ydata_profiling.model.summarizer import (
#      35     BaseSummarizer,
#      36     ProfilingSummarizer,
#      37     format_summary,
#      38     redact_summary,
#      39 )
#
# File c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\ydata_profiling\model\describe.py:20
#      18 from ydata_profiling.model.duplicates import get_duplicates
#      19 from ydata_profiling.model.missing import get_missing_active, get_missing_diagram
# ---> 20 from ydata_profiling.model.pairwise import get_scatter_plot, get_scatter_tasks
#      21 from ydata_profiling.model.sample import get_custom_sample, get_sample
#      22 from ydata_profiling.model.summarizer import BaseSummarizer
#
# File c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\ydata_profiling\model\pairwise.py:6
#       3 import pandas as pd
#       5 from ydata_profiling.config import Settings
# ----> 6 from ydata_profiling.visualisation.plot import scatter_pairwise
#       9 def get_scatter_tasks(
#      10     config: Settings, continuous_variables: list
#      11 ) -> List[Tuple[Any, Any]]:
#      12     if not config.interactions.continuous:
#
# File c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\ydata_profiling\visualisation\plot.py:5
#       2 import copy
#       3 from typing import Any, Callable, List, Optional, Tuple, Union
# ----> 5 import matplotlib
#       6 import numpy as np
#       7 import pandas as pd
#
# File c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\matplotlib\__init__.py:142
#     138 from packaging.version import parse as parse_version
#     140 # cbook must import matplotlib only within function
#     141 # definitions, so it is safe to import from it here.
# --> 142 from . import _api, _version, cbook, _docstring, rcsetup
#     143 from matplotlib.cbook import sanitize_sequence
#     144 from matplotlib._api import MatplotlibDeprecationWarning
#
# File c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\matplotlib\rcsetup.py:27
#      25 from matplotlib import _api, cbook
#      26 from matplotlib.cbook import ls_mapper
# ---> 27 from matplotlib.colors import Colormap, is_color_like
#      28 from matplotlib._fontconfig_pattern import parse_fontconfig_pattern
#      29 from matplotlib._enums import JoinStyle, CapStyle
#
# File c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\matplotlib\colors.py:56
#      54 import matplotlib as mpl
#      55 import numpy as np
# ---> 56 from matplotlib import _api, _cm, cbook, scale
#      57 from ._color_data import BASE_COLORS, TABLEAU_COLORS, CSS4_COLORS, XKCD_COLORS
#      60 class _ColorMapping(dict):
#
# File c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\matplotlib\scale.py:22
#      20 import matplotlib as mpl
#      21 from matplotlib import _api, _docstring
# ---> 22 from matplotlib.ticker import (
#      23     NullFormatter, ScalarFormatter, LogFormatterSciNotation, LogitFormatter,
#      24     NullLocator, LogLocator, AutoLocator, AutoMinorLocator,
#      25     SymmetricalLogLocator, AsinhLocator, LogitLocator)
#      26 from matplotlib.transforms import Transform, IdentityTransform
#      29 class ScaleBase:
#
# File c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\matplotlib\ticker.py:138
#     136 import matplotlib as mpl
#     137 from matplotlib import _api, cbook
# --> 138 from matplotlib import transforms as mtransforms
#     140 _log = logging.getLogger(__name__)
#     142 __all__ = ('TickHelper', 'Formatter', 'FixedFormatter',
#     143            'NullFormatter', 'FuncFormatter', 'FormatStrFormatter',
#     144            'StrMethodFormatter', 'ScalarFormatter', 'LogFormatter',
#    (...)    150            'MultipleLocator', 'MaxNLocator', 'AutoMinorLocator',
#     151            'SymmetricalLogLocator', 'AsinhLocator', 'LogitLocator')
#
# File c:\Users\ykarabekov\Documents\Python\user_scripts\sf_education_repo\.venv-sf\Lib\site-packages\matplotlib\transforms.py:49
#      46 from numpy.linalg import inv
#      48 from matplotlib import _api
# ---> 49 from matplotlib._path import (
#      50     affine_transform, count_bboxes_overlapping_bbox, update_path_extents)
#      51 from .path import Path
#      53 DEBUG = False
#
# ImportError: numpy.core.multiarray failed to import
